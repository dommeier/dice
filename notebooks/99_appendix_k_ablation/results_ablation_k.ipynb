# %%
# --- 0) Imports & paths ---
import pandas as pd
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
citeseq = pd.read_csv('k_ablation_citeseq.csv', index_col=0)
citeseq
# Out:
#          Dataset  Adjusted_Rand_Index  Mean_LISI_Score  Mean_Silhouette_Score  \
# Folder
# 10d     Denoised               0.7185           8.0453                 0.5535
# 10d         True               0.5925           8.4578                 0.5007
# 15d     Denoised               0.7159           6.9634                 0.6296
# 15d         True               0.7244           7.4046                 0.5277
# 20d     Denoised               0.7560           6.8079                 0.5591
# 20d         True               0.7163           6.6117                 0.4904
# 50d     Denoised               0.8282           5.8349                 0.5089
# 50d         True               0.6708           5.8726                 0.6289
# 5d      Denoised               0.6050          11.1725                 0.5603
# 5d          True               0.5067          10.4220                 0.6651
#
#         Silhouette_Benchmark  V_Measure
# Folder
# 10d                  -0.0988     0.7708
# ...

# %%
neo_cortex = pd.read_csv('k_ablation_neocortex.csv', index_col=0)
neo_cortex
# Out:
#          Dataset  Adjusted_Rand_Index  Mean_LISI_Score  Mean_Silhouette_Score  \
# Folder
# 100d    Denoised               0.4259           6.3095                 0.4377
# 100d        True               0.3369           6.0869                 0.3844
# 10d     Denoised               0.3649           6.1185                 0.4080
# 10d         True               0.3222           5.6981                 0.4151
# 15d     Denoised               0.3926           5.6644                 0.3954
# 15d         True               0.3080           5.3908                 0.4291
# 200d    Denoised               0.3675           6.5765                 0.3899
# 200d        True               0.3382           6.6067                 0.3600
# 20d     Denoised               0.3955           5.6552                 0.4311
# 20d         True               0.3981           5.5292                 0.4310
# 25d     Denoised               0.3811           5.8504                 0.4199
# ...
